# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Notebook ready for greenhouse ML project.")

# %%
df = pd.read_csv("../data/raw/20210703_greenhouse_data.csv")
df.head()
